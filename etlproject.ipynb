# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/NFL_2018_49ers.csv"
SF49ers_2018 = pd.read_csv(csv_file)
SF49ers_2018.head()
# Out:
#    Round Number              Date           Location             Home Team  \
# 0             1  09/09/2018 10:00  U.S. Bank Stadium     Minnesota Vikings
# 1             2  16/09/2018 13:05     Levi's Stadium   San Francisco 49ers
# 2             3  23/09/2018 10:00  Arrowhead Stadium    Kansas City Chiefs
# 3             4  30/09/2018 13:25     StubHub Center  Los Angeles Chargers
# 4             5  07/10/2018 13:25     Levi's Stadium   San Francisco 49ers
#
#              Away Team   Result
# 0  San Francisco 49ers  24 - 16
# 1        Detroit Lions  30 - 27
# 2  San Francisco 49ers  38 - 27
# 3  San Francisco 49ers  29 - 27
# 4    Arizona Cardinals  18 - 28

# %%
csv_file = "Resources/NFL_2017_49ers.csv"
SF49ers_2017 = pd.read_csv(csv_file)
SF49ers_2017.head()
# Out:
#    Round Number              Date              Location            Home Team  \
# 0             1  10/09/2017 13:25        Levi's Stadium  San Francisco 49ers
# 1             2  17/09/2017 13:25     CenturyLink Field     Seattle Seahawks
# 2             3  21/09/2017 17:25        Levi's Stadium  San Francisco 49ers
# 3             4  01/10/2017 13:05  U of Phoenix Stadium    Arizona Cardinals
# 4             5  08/10/2017 10:00     Lucas Oil Stadium   Indianapolis Colts
#
#              Away Team   Result
# 0    Carolina Panthers   3 - 23
# 1  San Francisco 49ers   12 - 9
# 2     Los Angeles Rams  39 - 41
# 3  San Francisco 49ers  18 - 15
# 4  San Francisco 49ers  26 - 23

# %%
csv_file = "Resources/NFL_2016_49ers.csv"
SF49ers_2016 = pd.read_csv(csv_file)
SF49ers_2016.head()
# Out:
#    Round Number              Date                 Location  \
# 0             1  12/09/2016 19:20           Levi's Stadium
# 1             2  18/09/2016 10:00  Bank of America Stadium
# 2             3  25/09/2016 13:05        CenturyLink Field
# 3             4  02/10/2016 13:25           Levi's Stadium
# 4             5  06/10/2016 17:25           Levi's Stadium
#
#              Home Team            Away Team   Result
# 0  San Francisco 49ers     Los Angeles Rams   28 - 0
# 1    Carolina Panthers  San Francisco 49ers  46 - 27
# 2     Seattle Seahawks  San Francisco 49ers  37 - 18
# 3  San Francisco 49ers       Dallas Cowboys  17 - 24
# 4  San Francisco 49ers    Arizona Cardinals  21 - 33

# %%
csv_file = "Resources/49ers_data.csv"
SF49ers_Data = pd.read_csv(csv_file)
SF49ers_Data.head()
# Out:
#                Date           Location             Home Team  \
# 0      9/9/18 10:00  U.S. Bank Stadium     Minnesota Vikings
# 1  16/09/2018 13:05     Levi's Stadium   San Francisco 49ers
# 2  23/09/2018 10:00  Arrowhead Stadium    Kansas City Chiefs
# 3  30/09/2018 13:25     StubHub Center  Los Angeles Chargers
# 4     7/10/18 13:25     Levi's Stadium   San Francisco 49ers
#
#              Away Team   Result
# 0  San Francisco 49ers  24 - 16
# 1        Detroit Lions  30 - 27
# 2  San Francisco 49ers  38 - 27
# 3  San Francisco 49ers  29 - 27
# 4    Arizona Cardinals  18 - 28

# %%
csv_file = "Resources/sportsref_data.csv"
sportsref = pd.read_csv(csv_file)
sportsref
# Out:
#       Rk   Tm    Year      Date   Time  LTime Unnamed: 6  Opp  Week    G#  \
# 0    NaN  NaN     NaN       NaN    NaN    NaN        NaN  NaN   NaN   NaN
# 1    1.0  SFO  2013.0    9/8/13   4:26   1:26        NaN  GNB   1.0   1.0
# 2    2.0  SFO  2018.0   11/1/18   8:20   5:20        NaN  OAK   9.0   9.0
# 3    3.0  SFO  2013.0  11/25/13   8:40   8:40          @  WAS  12.0  11.0
# 4    4.0  SFO  2018.0  12/30/18   4:25   1:25          @  LAR  17.0  16.0
# 5    5.0  SFO  2016.0  11/27/16   1:00   1:00          @  MIA  12.0  11.0
# 6    6.0  SFO  2014.0  10/13/14   8:30   7:30          @  STL   6.0   6.0
# 7    7.0  SFO  2017.0  12/31/17   4:25   1:25          @  LAR  17.0  16.0
# 8    8.0  SFO  2015.0  12/27/15   1:03   1:03          @  DET  16.0  15.0
# 9    9.0  SFO  2014.0  12/28/14   4:25   1:25        NaN  ARI  17.0  16.0
# 10  10.0  SFO  2015.0   9/20/15   1:02   1:02          @  PIT   2.0   2.0
# 11  11.0  SFO  2017.0  11/12/17   4:25   1:25        NaN  NYG  10.0  10.0
# ...

# %%
sportsref.columns
# Out:
# Index(['Rk', 'Tm', 'Year', 'Date', 'Time', 'LTime', 'Unnamed: 6', 'Opp',
#        'Week', 'G#', 'Day', 'Result', 'OT', 'Spread', 'vs. Line', 'Over/Under',
#        'OU Result', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD', 'Int', 'Sk', 'Yds.1',
#        'Rate'],
#       dtype='object')

# %%
#rename fields
sportsref.rename(columns={'Rk':'Rank',
                          'Tm':'Team',
                         }, 
                 inplace=True)

# %%
sportsref.columns
# Out:
# Index(['Rank', 'Team', 'Year', 'Date', 'Time', 'LTime', 'Unnamed: 6', 'Opp',
#        'Week', 'G#', 'Day', 'Result', 'OT', 'Spread', 'vs. Line', 'Over/Under',
#        'OU Result', 'Cmp', 'Att', 'Cmp%', 'Yds', 'TD', 'Int', 'Sk', 'Yds.1',
#        'Rate'],
#       dtype='object')

# %%
sportsref_db = sportsref[['Team','Date','Opp','vs. Line','OU Result','Spread']]

# %% [markdown]
# #### sportsref_db

# %%
pip install psycopg2-binary
# Out:
# ...
#     100% |████████████████████████████████| 1.6MB 3.4MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
rds_connection_string = "postgres:postgres@localhost:5432/ETLproject_DB"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table.names()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-f3c35da634e9> in <module>
# ----> 1 engine.table.names()
#
# AttributeError: 'Engine' object has no attribute 'table'
